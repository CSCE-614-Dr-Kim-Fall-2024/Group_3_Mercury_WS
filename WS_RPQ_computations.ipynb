# %% [markdown]
# Mercury with RPQ

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, datasets, transforms
from torch.utils.data import DataLoader, random_split
import os
import time

# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Parameters
input_size = 224
batch_size = 16
class_subset = 5  # Only use 5 classes
random_matrix = torch.randn(input_size * input_size * 3, 512, device=device)  # RPQ matrix
cache_limit = 5000

# Cache for RPQ signatures
cache = {}
cache_hits = 0
cache_misses = 0
total_computations = 0

# Data transformations
data_transforms = {
    "train": transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    "val": transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

# Load TinyImageNet dataset (subset of 80 classes)
data_dir = "./data/tiny-imagenet-200/train"
full_dataset = datasets.ImageFolder(data_dir, transform=data_transforms["train"])

subset_classes = list(full_dataset.class_to_idx.keys())[:class_subset]
filtered_samples = [s for s in full_dataset.samples if s[1] < class_subset]
full_dataset.samples = filtered_samples
full_dataset.targets = [s[1] for s in filtered_samples]

# Split dataset
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

# Model setup
model = models.resnet50(pretrained=False)
model.fc = nn.Linear(model.fc.in_features, class_subset)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# Training with RPQ and WS
def train_model_with_rpq_and_ws(model, train_loader, val_loader, criterion, optimizer, num_epochs=10):
    global cache_hits, cache_misses, total_computations

    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}/{num_epochs}")
        print("-" * 20)

        # Training phase
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            # RPQ: Compute binary signatures
            inputs_flat = inputs.view(inputs.size(0), -1)
            projections = torch.matmul(inputs_flat, random_matrix)
            signatures = (projections > 0).int().tolist()

            # Check cache
            for sig in signatures:
                sig_tuple = tuple(sig)
                if sig_tuple in cache:
                    cache_hits += 1
                else:
                    cache_misses += 1
                    cache[sig_tuple] = True
                    if len(cache) > cache_limit:
                        cache.pop(next(iter(cache)))  # Remove oldest entry

            # Process batch
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Update stats
            total_computations += inputs.size(0)
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += torch.sum(preds == labels).item()
            total += labels.size(0)

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = correct / total
        print(f"Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.4f}")

    print(f"Cache hits: {cache_hits}, Cache misses: {cache_misses}")
    print(f"Total computations: {total_computations}, Cache hit rate: {cache_hits / (cache_hits + cache_misses):.2f}")

# Train the model
train_model_with_rpq_and_ws(model, train_loader, val_loader, criterion, optimizer,200)
# Out:
# Using device: cuda
# Epoch 1/200
# --------------------
# Train Loss: 3.2315, Train Acc: 0.2145
# Epoch 2/200
# --------------------
# Train Loss: 1.7738, Train Acc: 0.2180
# Epoch 3/200
# --------------------
# Train Loss: 1.6224, Train Acc: 0.2905
# Epoch 4/200
# --------------------
# Train Loss: 1.6041, Train Acc: 0.2920
# Epoch 5/200
# --------------------
# Train Loss: 1.4889, Train Acc: 0.3740
# Epoch 6/200
# --------------------
# Train Loss: 1.4215, Train Acc: 0.4040
# Epoch 7/200
# --------------------
# Train Loss: 1.3925, Train Acc: 0.4290
# Epoch 8/200
# --------------------
# Train Loss: 1.3931, Train Acc: 0.4385
# Epoch 9/200
# --------------------
# Train Loss: 1.3701, Train Acc: 0.4370
# Epoch 10/200
# --------------------
# Train Loss: 1.3704, Train Acc: 0.4420
# Epoch 11/200
# --------------------
# Train Loss: 1.3172, Train Acc: 0.4605
# Epoch 12/200
# --------------------
# Train Loss: 1.2895, Train Acc: 0.4650
# Epoch 13/200
# --------------------
# Train Loss: 1.2923, Train Acc: 0.4805
# Epoch 14/200
# --------------------
# Train Loss: 1.2864, Train Acc: 0.4810
# Epoch 15/200
# --------------------
# Train Loss: 1.2847, Train Acc: 0.4805
# Epoch 16/200
# --------------------
# Train Loss: 1.2390, Train Acc: 0.5045
# Epoch 17/200
# --------------------
# Train Loss: 1.2447, Train Acc: 0.5025
# Epoch 18/200
# --------------------
# Train Loss: 1.2584, Train Acc: 0.4870
# Epoch 19/200
# --------------------
# Train Loss: 1.2349, Train Acc: 0.5070
# Epoch 20/200
# --------------------
# Train Loss: 1.2165, Train Acc: 0.5035
# Epoch 21/200
# --------------------
# Train Loss: 1.2219, Train Acc: 0.5100
# Epoch 22/200
# --------------------
# Train Loss: 1.1910, Train Acc: 0.5240
# Epoch 23/200
# --------------------
# Train Loss: 1.1999, Train Acc: 0.5275
# Epoch 24/200
# --------------------
# Train Loss: 1.1661, Train Acc: 0.5260
# Epoch 25/200
# --------------------
# Train Loss: 1.1879, Train Acc: 0.5185
# Epoch 26/200
# --------------------
# Train Loss: 1.2337, Train Acc: 0.4980
# Epoch 27/200
# --------------------
# Train Loss: 1.2034, Train Acc: 0.5115
# Epoch 28/200
# --------------------
# Train Loss: 1.1863, Train Acc: 0.5120
# Epoch 29/200
# --------------------
# Train Loss: 1.1620, Train Acc: 0.5480
# Epoch 30/200
# --------------------
# Train Loss: 1.1765, Train Acc: 0.5240
# Epoch 31/200
# --------------------
# Train Loss: 1.1536, Train Acc: 0.5445
# Epoch 32/200
# --------------------
# Train Loss: 1.1670, Train Acc: 0.5325
# Epoch 33/200
# --------------------
# Train Loss: 1.1688, Train Acc: 0.5320
# Epoch 34/200
# --------------------
# Train Loss: 1.1280, Train Acc: 0.5530
# Epoch 35/200
# --------------------
# Train Loss: 1.1161, Train Acc: 0.5535
# Epoch 36/200
# --------------------
# Train Loss: 1.1046, Train Acc: 0.5520
# Epoch 37/200
# --------------------
# Train Loss: 1.1230, Train Acc: 0.5620
# Epoch 38/200
# --------------------
# Train Loss: 1.1220, Train Acc: 0.5570
# Epoch 39/200
# --------------------
# Train Loss: 1.1105, Train Acc: 0.5680
# Epoch 40/200
# --------------------
# Train Loss: 1.1074, Train Acc: 0.5535
# Epoch 41/200
# --------------------
# Train Loss: 1.0860, Train Acc: 0.5680
# Epoch 42/200
# --------------------
# Train Loss: 1.0728, Train Acc: 0.5835
# Epoch 43/200
# --------------------
# Train Loss: 1.0827, Train Acc: 0.5740
# Epoch 44/200
# --------------------
# Train Loss: 1.0801, Train Acc: 0.5700
# Epoch 45/200
# --------------------
# Train Loss: 1.0571, Train Acc: 0.5710
# Epoch 46/200
# --------------------
# Train Loss: 1.0710, Train Acc: 0.5690
# Epoch 47/200
# --------------------
# Train Loss: 1.0507, Train Acc: 0.5885
# Epoch 48/200
# --------------------
# Train Loss: 1.0439, Train Acc: 0.5940
# Epoch 49/200
# --------------------
# Train Loss: 1.0357, Train Acc: 0.5935
# Epoch 50/200
# --------------------
# Train Loss: 1.0286, Train Acc: 0.5825
# Epoch 51/200
# --------------------
# Train Loss: 1.0175, Train Acc: 0.5970
# Epoch 52/200
# --------------------
# Train Loss: 1.0302, Train Acc: 0.6045
# Epoch 53/200
# --------------------
# Train Loss: 1.0086, Train Acc: 0.5970
# Epoch 54/200
# --------------------
# Train Loss: 0.9981, Train Acc: 0.6065
# Epoch 55/200
# --------------------
# Train Loss: 1.0014, Train Acc: 0.6220
# Epoch 56/200
# --------------------
# Train Loss: 1.0188, Train Acc: 0.6010
# Epoch 57/200
# --------------------
# Train Loss: 0.9622, Train Acc: 0.6300
# Epoch 58/200
# --------------------
# Train Loss: 1.0061, Train Acc: 0.6015
# Epoch 59/200
# --------------------
# Train Loss: 1.0150, Train Acc: 0.6195
# Epoch 60/200
# --------------------
# Train Loss: 0.9776, Train Acc: 0.6255
# Epoch 61/200
# --------------------
# Train Loss: 0.9580, Train Acc: 0.6235
# Epoch 62/200
# --------------------
# Train Loss: 0.9908, Train Acc: 0.6155
# Epoch 63/200
# --------------------
# Train Loss: 0.9815, Train Acc: 0.6275
# Epoch 64/200
# --------------------
# Train Loss: 0.9619, Train Acc: 0.6245
# Epoch 65/200
# --------------------
# Train Loss: 0.9817, Train Acc: 0.6145
# Epoch 66/200
# --------------------
# Train Loss: 0.9915, Train Acc: 0.6160
# Epoch 67/200
# --------------------
# Train Loss: 0.9497, Train Acc: 0.6340
# Epoch 68/200
# --------------------
# Train Loss: 0.9718, Train Acc: 0.6215
# Epoch 69/200
# --------------------
# Train Loss: 1.0095, Train Acc: 0.5930
# Epoch 70/200
# --------------------
# Train Loss: 0.9371, Train Acc: 0.6285
# Epoch 71/200
# --------------------
# Train Loss: 0.9400, Train Acc: 0.6300
# Epoch 72/200
# --------------------
# Train Loss: 0.9592, Train Acc: 0.6220
# Epoch 73/200
# --------------------
# Train Loss: 0.9255, Train Acc: 0.6315
# Epoch 74/200
# --------------------
# Train Loss: 0.9484, Train Acc: 0.6360
# Epoch 75/200
# --------------------
# Train Loss: 0.9198, Train Acc: 0.6365
# Epoch 76/200
# --------------------
# Train Loss: 0.9190, Train Acc: 0.6430
# Epoch 77/200
# --------------------
# Train Loss: 0.9072, Train Acc: 0.6535
# Epoch 78/200
# --------------------
# Train Loss: 0.8912, Train Acc: 0.6660
# Epoch 79/200
# --------------------
# Train Loss: 0.8873, Train Acc: 0.6545
# Epoch 80/200
# --------------------
# Train Loss: 0.8788, Train Acc: 0.6535
# Epoch 81/200
# --------------------
# Train Loss: 0.8768, Train Acc: 0.6570
# Epoch 82/200
# --------------------
# Train Loss: 0.8758, Train Acc: 0.6650
# Epoch 83/200
# --------------------
# Train Loss: 0.8671, Train Acc: 0.6565
# Epoch 84/200
# --------------------
# Train Loss: 0.8599, Train Acc: 0.6625
# Epoch 85/200
# --------------------
# Train Loss: 0.8766, Train Acc: 0.6585
# Epoch 86/200
# --------------------
# Train Loss: 0.8669, Train Acc: 0.6515
# Epoch 87/200
# --------------------
# Train Loss: 0.8454, Train Acc: 0.6605
# Epoch 88/200
# --------------------
# Train Loss: 0.8408, Train Acc: 0.6795
# Epoch 89/200
# --------------------
# Train Loss: 0.8163, Train Acc: 0.6860
# Epoch 90/200
# --------------------
# Train Loss: 0.8544, Train Acc: 0.6755
# Epoch 91/200
# --------------------
# Train Loss: 0.8175, Train Acc: 0.6780
# Epoch 92/200
# --------------------
# Train Loss: 0.8241, Train Acc: 0.6755
# Epoch 93/200
# --------------------
# Train Loss: 0.7856, Train Acc: 0.7030
# Epoch 94/200
# --------------------
# Train Loss: 0.8088, Train Acc: 0.6820
# Epoch 95/200
# --------------------
# Train Loss: 0.7947, Train Acc: 0.6985
# Epoch 96/200
# --------------------
# Train Loss: 0.8086, Train Acc: 0.6755
# Epoch 97/200
# --------------------
# Train Loss: 0.8027, Train Acc: 0.6875
# Epoch 98/200
# --------------------
# Train Loss: 0.8153, Train Acc: 0.6885
# Epoch 99/200
# --------------------
# Train Loss: 0.7874, Train Acc: 0.6870
# Epoch 100/200
# --------------------
# Train Loss: 0.7844, Train Acc: 0.6995
# Epoch 101/200
# --------------------
# Train Loss: 0.7848, Train Acc: 0.6945
# Epoch 102/200
# --------------------
# Train Loss: 0.7649, Train Acc: 0.7015
# Epoch 103/200
# --------------------
# Train Loss: 0.7713, Train Acc: 0.7120
# Epoch 104/200
# --------------------
# Train Loss: 0.7426, Train Acc: 0.7215
# Epoch 105/200
# --------------------
# Train Loss: 0.7668, Train Acc: 0.6970
# Epoch 106/200
# --------------------
# Train Loss: 0.7792, Train Acc: 0.6990
# Epoch 107/200
# --------------------
# Train Loss: 0.7752, Train Acc: 0.7000
# Epoch 108/200
# --------------------
# Train Loss: 0.7414, Train Acc: 0.7110
# Epoch 109/200
# --------------------
# Train Loss: 0.7083, Train Acc: 0.7275
# Epoch 110/200
# --------------------
# Train Loss: 0.7372, Train Acc: 0.7165
# Epoch 111/200
# --------------------
# Train Loss: 0.6898, Train Acc: 0.7400
# Epoch 112/200
# --------------------
# Train Loss: 0.7391, Train Acc: 0.7090
# Epoch 113/200
# --------------------
# Train Loss: 0.7286, Train Acc: 0.7175
# Epoch 114/200
# --------------------
# Train Loss: 0.7180, Train Acc: 0.7190
# Epoch 115/200
# --------------------
# Train Loss: 0.7286, Train Acc: 0.7220
# Epoch 116/200
# --------------------
# Train Loss: 0.6835, Train Acc: 0.7380
# Epoch 117/200
# --------------------
# Train Loss: 0.7159, Train Acc: 0.7270
# Epoch 118/200
# --------------------
# Train Loss: 0.6974, Train Acc: 0.7350
# Epoch 119/200
# --------------------
# Train Loss: 0.6812, Train Acc: 0.7415
# Epoch 120/200
# --------------------
# Train Loss: 0.7023, Train Acc: 0.7385
# Epoch 121/200
# --------------------
# Train Loss: 0.6989, Train Acc: 0.7400
# Epoch 122/200
# --------------------
# Train Loss: 0.6809, Train Acc: 0.7430
# Epoch 123/200
# --------------------
# Train Loss: 0.6773, Train Acc: 0.7350
# Epoch 124/200
# --------------------
# Train Loss: 0.6993, Train Acc: 0.7195
# Epoch 125/200
# --------------------
# Train Loss: 0.7050, Train Acc: 0.7235
# Epoch 126/200
# --------------------
# Train Loss: 0.6719, Train Acc: 0.7410
# Epoch 127/200
# --------------------
# Train Loss: 0.6734, Train Acc: 0.7470
# Epoch 128/200
# --------------------
# Train Loss: 0.6453, Train Acc: 0.7550
# Epoch 129/200
# --------------------
# Train Loss: 0.6405, Train Acc: 0.7565
# Epoch 130/200
# --------------------
# Train Loss: 0.6623, Train Acc: 0.7545
# Epoch 131/200
# --------------------
# Train Loss: 0.6296, Train Acc: 0.7555
# Epoch 132/200
# --------------------
# Train Loss: 0.6402, Train Acc: 0.7495
# Epoch 133/200
# --------------------
# Train Loss: 0.6690, Train Acc: 0.7625
# Epoch 134/200
# --------------------
# Train Loss: 0.6421, Train Acc: 0.7580
# Epoch 135/200
# --------------------
# Train Loss: 0.6285, Train Acc: 0.7520
# Epoch 136/200
# --------------------
# Train Loss: 0.6807, Train Acc: 0.7395
# Epoch 137/200
# --------------------
# Train Loss: 0.6240, Train Acc: 0.7565
# Epoch 138/200
# --------------------
# Train Loss: 0.6390, Train Acc: 0.7610
# Epoch 139/200
# --------------------
# Train Loss: 0.6405, Train Acc: 0.7545
# Epoch 140/200
# --------------------
# Train Loss: 0.6141, Train Acc: 0.7770
# Epoch 141/200
# --------------------
# Train Loss: 0.6435, Train Acc: 0.7620
# Epoch 142/200
# --------------------
# Train Loss: 0.6295, Train Acc: 0.7590
# Epoch 143/200
# --------------------
# Train Loss: 0.6499, Train Acc: 0.7535
# Epoch 144/200
# --------------------
# Train Loss: 0.6502, Train Acc: 0.7620
# Epoch 145/200
# --------------------
# Train Loss: 0.6011, Train Acc: 0.7720
# Epoch 146/200
# --------------------
# Train Loss: 0.6082, Train Acc: 0.7695
# Epoch 147/200
# --------------------
# Train Loss: 0.6100, Train Acc: 0.7665
# Epoch 148/200
# --------------------
# Train Loss: 0.6090, Train Acc: 0.7635
# Epoch 149/200
# --------------------
# Train Loss: 0.5859, Train Acc: 0.7740
# Epoch 150/200
# --------------------
# Train Loss: 0.6290, Train Acc: 0.7640
# Epoch 151/200
# --------------------
# Train Loss: 0.5726, Train Acc: 0.7805
# Epoch 152/200
# --------------------
# Train Loss: 0.5888, Train Acc: 0.7730
# Epoch 153/200
# --------------------
# Train Loss: 0.5738, Train Acc: 0.7855
# Epoch 154/200
# --------------------
# Train Loss: 0.5576, Train Acc: 0.7795
# Epoch 155/200
# --------------------
# Train Loss: 0.5602, Train Acc: 0.7890
# Epoch 156/200
# --------------------
# Train Loss: 0.5845, Train Acc: 0.7640
# Epoch 157/200
# --------------------
# Train Loss: 0.5380, Train Acc: 0.8000
# Epoch 158/200
# --------------------
# Train Loss: 0.5830, Train Acc: 0.7755
# Epoch 159/200
# --------------------
# Train Loss: 0.5460, Train Acc: 0.7910
# Epoch 160/200
# --------------------
# Train Loss: 0.5604, Train Acc: 0.7790
# Epoch 161/200
# --------------------
# Train Loss: 0.5583, Train Acc: 0.7945
# Epoch 162/200
# --------------------
# Train Loss: 0.5094, Train Acc: 0.8045
# Epoch 163/200
# --------------------
# Train Loss: 0.5256, Train Acc: 0.7950
# Epoch 164/200
# --------------------
# Train Loss: 0.5065, Train Acc: 0.8060
# Epoch 165/200
# --------------------
# Train Loss: 0.5207, Train Acc: 0.8060
# Epoch 166/200
# --------------------
# Train Loss: 0.5451, Train Acc: 0.7895
# Epoch 167/200
# --------------------
# Train Loss: 0.5047, Train Acc: 0.8160
# Epoch 168/200
# --------------------
# Train Loss: 0.5298, Train Acc: 0.7985
# Epoch 169/200
# --------------------
# Train Loss: 0.5221, Train Acc: 0.8035
# Epoch 170/200
# --------------------
# Train Loss: 0.5331, Train Acc: 0.7975
# Epoch 171/200
# --------------------
# Train Loss: 0.5155, Train Acc: 0.8135
# Epoch 172/200
# --------------------
# Train Loss: 0.5389, Train Acc: 0.8035
# Epoch 173/200
# --------------------
# Train Loss: 0.5155, Train Acc: 0.8100
# Epoch 174/200
# --------------------
# Train Loss: 0.5303, Train Acc: 0.7975
# Epoch 175/200
# --------------------
# Train Loss: 0.4847, Train Acc: 0.8225
# Epoch 176/200
# --------------------
# Train Loss: 0.4958, Train Acc: 0.8155
# Epoch 177/200
# --------------------
# Train Loss: 0.4851, Train Acc: 0.8210
# Epoch 178/200
# --------------------
# Train Loss: 0.4755, Train Acc: 0.8280
# Epoch 179/200
# --------------------
# Train Loss: 0.5286, Train Acc: 0.8025
# Epoch 180/200
# --------------------
# Train Loss: 0.4769, Train Acc: 0.8175
# Epoch 181/200
# --------------------
# Train Loss: 0.4944, Train Acc: 0.8120
# Epoch 182/200
# --------------------
# Train Loss: 0.4387, Train Acc: 0.8350
# Epoch 183/200
# --------------------
# Train Loss: 0.4912, Train Acc: 0.8130
# Epoch 184/200
# --------------------
# Train Loss: 0.4597, Train Acc: 0.8385
# Epoch 185/200
# --------------------
# Train Loss: 0.4558, Train Acc: 0.8315
# Epoch 186/200
# --------------------
# Train Loss: 0.4854, Train Acc: 0.8130
# Epoch 187/200
# --------------------
# Train Loss: 0.4794, Train Acc: 0.8295
# Epoch 188/200
# --------------------
# Train Loss: 0.4654, Train Acc: 0.8240
# Epoch 189/200
# --------------------
# Train Loss: 0.4468, Train Acc: 0.8320
# Epoch 190/200
# --------------------
# Train Loss: 0.4644, Train Acc: 0.8325
# Epoch 191/200
# --------------------
# Train Loss: 0.4542, Train Acc: 0.8310
# Epoch 192/200
# --------------------
# Train Loss: 0.4670, Train Acc: 0.8170
# Epoch 193/200
# --------------------
# Train Loss: 0.4381, Train Acc: 0.8415
# Epoch 194/200
# --------------------
# Train Loss: 0.4474, Train Acc: 0.8365
# Epoch 195/200
# --------------------
# Train Loss: 0.4423, Train Acc: 0.8435
# Epoch 196/200
# --------------------
# Train Loss: 0.4479, Train Acc: 0.8375
# Epoch 197/200
# --------------------
# Train Loss: 0.4353, Train Acc: 0.8360
# Epoch 198/200
# --------------------
# Train Loss: 0.4562, Train Acc: 0.8330
# Epoch 199/200
# --------------------
# Train Loss: 0.4418, Train Acc: 0.8375
# Epoch 200/200
# --------------------
# Train Loss: 0.4301, Train Acc: 0.8445
# Cache hits: 9, Cache misses: 399991
# Total computations: 400000, Cache hit rate: 0.00

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, datasets, transforms
from torch.utils.data import DataLoader, random_split
import os

# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Parameters
input_size = 224  # Image size for ResNet
batch_size = 16
class_subset = 5  # Number of classes to use
num_epochs = 200
random_matrix = torch.randn(input_size * input_size * 3, 512, device=device)  # RPQ projection matrix
cache_limit = 5000  # Maximum cache size

# Cache and statistics
cache = {}  # LRU-like cache
cache_hits = 0  # Count of cache hits
cache_misses = 0  # Count of cache misses
skipped_computations = 0  # Count of computations skipped
total_computations = 0  # Total attempted computations


# Cache update function
def update_cache(signature):
    """
    Updates the cache with the given RPQ signature.
    If the signature is found, count it as a cache hit and skip computation.
    Otherwise, add the signature to the cache, removing the oldest if full.
    """
    global cache_hits, cache_misses, skipped_computations
    if signature in cache:
        cache_hits += 1
        skipped_computations += 1  # Skip computation for cache hit
    else:
        cache_misses += 1
        if len(cache) >= cache_limit:
            cache.pop(next(iter(cache)))  # Remove oldest entry (FIFO)
        cache[signature] = True


# Data transformations
data_transforms = {
    "train": transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

# Load TinyImageNet dataset
data_dir = "./data/tiny-imagenet-200/train"
full_dataset = datasets.ImageFolder(data_dir, transform=data_transforms["train"])

# Filter for the selected number of classes
subset_classes = list(full_dataset.class_to_idx.keys())[:class_subset]
filtered_samples = [s for s in full_dataset.samples if s[1] < class_subset]
full_dataset.samples = filtered_samples
full_dataset.targets = [s[1] for s in filtered_samples]

# Split dataset into training and validation sets
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# DataLoader
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)

# Model setup
model = models.resnet50(pretrained=False)  # ResNet-50 model
model.fc = nn.Linear(model.fc.in_features, class_subset)  # Adjust final layer for the selected classes
model = model.to(device)

# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)


# Training function
def train_model_with_rpq(model, train_loader, criterion, optimizer, num_epochs):
    """
    Trains the model using RPQ with cache management.
    Produces a report at the end of training with detailed metrics.
    """
    global cache_hits, cache_misses, skipped_computations, total_computations

    total_loss = 0.0  # Accumulate total loss across epochs

    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}/{num_epochs} in progress...")

        # Training phase
        model.train()
        epoch_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            # RPQ Signature Computation
            inputs_flat = inputs.view(inputs.size(0), -1)  # Flatten input images
            projections = torch.matmul(inputs_flat, random_matrix)  # Project inputs
            signatures = (projections > 0).int()  # Convert projections to binary signatures
            
            # Cache check and management
            for sig in signatures:
                sig_tuple = tuple(sig.tolist())  # Convert tensor to tuple for hashing
                update_cache(sig_tuple)

            # Model forward pass and backpropagation
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Update statistics
            total_computations += inputs.size(0)
            epoch_loss += loss.item() * inputs.size(0)

        total_loss += epoch_loss

    # Final report
    print("\n=== Training Report ===")
    print(f"Total epochs: {num_epochs}")
    print(f"Total training loss: {total_loss / len(train_loader.dataset):.4f}")
    print(f"Cache hits: {cache_hits}")
    print(f"Cache misses: {cache_misses}")
    print(f"Skipped computations: {skipped_computations}")
    print(f"Total computations: {total_computations}")
    print(f"Cache hit rate: {cache_hits / (cache_hits + cache_misses):.2f}")
    print(f"Computation skip rate: {skipped_computations / total_computations:.2f}")
    print("========================")


# Train the model
train_model_with_rpq(model, train_loader, criterion, optimizer, num_epochs)
